# %% [markdown]
# * Ctrl + Enter 현재 셀 실행
# * Shift + Enter 현재 셀 실행 및 다음 셀 선택
# * A     위에 셀 삽입
# * B     아래에 셀 삽입
# * Y     현재 셀 코드 셀로 전환
# * M     현재 셀 마크다운 셀로 전환

# %% [markdown]
# # 주석

# %%
# 이것은 주석입니다
print('Hello World') # 이것도 주석입니다
# Out:
# Hello World

# %%
'''
이것은 주석입니다
이렇게 여러 줄 주석을 넣을 수 있습니다
'''
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# # 입력과 출력

# %%
x = input('입력해주세요: ') # 문자열로 받는다 !
x + x
# Out:
# '3030'

# %%
print('010', '9913', '7552', sep = '-')
# Out:
# 010-9913-7552

# %%
print('hello world', end = '!')
# Out:
# hello world!

# %%
class Character : 
    def __str__(self):
        return 'a'
    
    def __repr__(self):
        return 'b'
    
hero = Character()
print(hero)
hero
# Out:
# a
# b

# %% [markdown]
# # 변수
#  * python 에서 변수는 포스트잇이다. 값을 담는 것이 아니라 가리킨다 !
