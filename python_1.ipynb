# %% [markdown]
# * Ctrl + Enter 현재 셀 실행
# * Shift + Enter 현재 셀 실행 및 다음 셀 선택
# * A     위에 셀 삽입
# * B     아래에 셀 삽입
# * Y     현재 셀 코드 셀로 전환
# * M     현재 셀 마크다운 셀로 전환

# %% [markdown]
# # 주석

# %%
# 이것은 주석입니다
print('Hello World') # 이것도 주석입니다
# Out:
# Hello World

# %%
'''
이것은 주석입니다
이렇게 여러 줄 주석을 넣을 수 있습니다
'''
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# # 입력과 출력

# %%
x = input('입력해주세요: ') # 문자열로 받는다 !
x + x
# Out:
# '3030'

# %%
print('010', '9913', '7552', sep = '-')
# Out:
# 010-9913-7552

# %%
print('hello world', end = '!')
# Out:
# hello world!

# %%
class Character : 
    def __str__(self):
        return a
    
    def __repr__(self):
        return b
    
hero = Character()
print(hero)
hero
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\정식\Desktop\개발\pythonStudy\python_1.ipynb 셀 9 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/%EC%A0%95%EC%8B%9D/Desktop/%EA%B0%9C%EB%B0%9C/pythonStudy/python_1.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> class Character :
#       <a href='vscode-notebook-cell:/c%3A/Users/%EC%A0%95%EC%8B%9D/Desktop/%EA%B0%9C%EB%B0%9C/pythonStudy/python_1.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a>     def __str__(self):
#       <a href='vscode-notebook-cell:/c%3A/Users/%EC%A0%95%EC%8B%9D/Desktop/%EA%B0%9C%EB%B0%9C/pythonStudy/python_1.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a>         return a
#
# c:\Users\정식\Desktop\개발\pythonStudy\python_1.ipynb 셀 9 line 8
#       <a href='vscode-notebook-cell:/c%3A/Users/%EC%A0%95%EC%8B%9D/Desktop/%EA%B0%9C%EB%B0%9C/pythonStudy/python_1.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a> def __repr__(self):
#       <a href='vscode-notebook-cell:/c%3A/Users/%EC%A0%95%EC%8B%9D/Desktop/%EA%B0%9C%EB%B0%9C/pythonStudy/python_1.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a>     return b
# ----> <a href='vscode-notebook-cell:/c%3A/Users/%EC%A0%95%EC%8B%9D/Desktop/%EA%B0%9C%EB%B0%9C/pythonStudy/python_1.ipynb#X14sZmlsZQ%3D%3D?line=7'>8</a> hero = Character()
#       <a href='vscode-notebook-cell:/c%3A/Users/%EC%A0%95%EC%8B%9D/Desktop/%EA%B0%9C%EB%B0%9C/pythonStudy/python_1.ipynb#X14sZmlsZQ%3D%3D?line=8'>9</a> print(hero)
#      <a href='vscode-notebook-cell:/c%3A/Users/%EC%A0%95%EC%8B%9D/Desktop/%EA%B0%9C%EB%B0%9C/pythonStudy/python_1.ipynb#X14sZmlsZQ%3D%3D?line=9'>10</a> hero
#
# NameError: name 'Character' is not defined
